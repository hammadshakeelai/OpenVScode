# %% [markdown]
# # OpenVScode Mobile - Python Jupyter Test
# This notebook verifies that the local Python Jupyter kernel (`ipykernel`) is operational.

# %%
import sys
import platform

print(f"Python Version: {sys.version}")
print(f"Platform: {platform.platform()}")
print("Jupyter Python kernel working successfully on mobile!")

# %%
# Quick calculation
data = [x**2 for x in range(1, 15)]
data

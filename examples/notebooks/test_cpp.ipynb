// %% [markdown]
// # OpenVScode Mobile - C++ Jupyter Test
// This notebook verifies that the local C++ Jupyter kernel (`jupyter-cpp-kernel`) is operational with Clang++ on mobile.

// %%
#include <iostream>

int main() {
    std::cout << "Hello from C++ in a Jupyter Notebook on Mobile!" << std::endl;
    return 0;
}

// %%
#include <iostream>
#include <vector>
#include <numeric>

int main() {
    std::vector<int> v = {10, 20, 30, 40, 50};
    int total = std::accumulate(v.begin(), v.end(), 0);
    std::cout << "Calculated Total in C++ cell: " << total << std::endl;
    return 0;
}
